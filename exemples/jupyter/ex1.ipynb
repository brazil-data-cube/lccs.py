# %% [markdown]
# ## <span style="color:#336699">Land Cover Classification System - Python Client API [<img src="img/bdc-logo.png" alt="Brazil Data Cube - Python Sample Client" style="height:100px;" align="right">](https://github.com/brazil-data-cube/lccs.py)</span>
#
# <hr style="border:2px solid #0077b9;">
#
# ### <span style="color:#336699"> Examples of lccs.py</span>

# %% [markdown]
# ####  Import the required libraries
# <hr style="border:1px solid #0077b9;">

# %%
import lccs

service = lccs.LCCS('http://localhost:5000/')

lccs.__version__
# Out:
# '0.2.0'

# %%
service
# Out:
# lccs("http://localhost:5000")

# %%
class_system = service.classification_system(system_id='MapBiomas4.1')
class_system
# Out:
# {'authority_name': 'Projeto de Mapeamento Anual da Cobertura e Uso do Solo no Brasil',
#  'description': 'Legenda do MapBiomas de Uso e Cobertura da Terra Versão 4.0 e 4.1',
#  'id': 23,
#  'links': [{'href': 'http://localhost:5000/classification_system/MapBiomas4.1',
#    'rel': 'self',
#    'title': 'Link to Classification System',
#    'type': 'application/json'},
#   {'href': 'http://localhost:5000/classification_system/MapBiomas4.1/classes',
#    'rel': 'classes',
#    'title': 'Link to Classification System Classes',
#    'type': 'application/json'},
#   {'href': 'http://localhost:5000/mappings/MapBiomas4.1',
#    'rel': 'mappings',
#    'title': 'Link to Classification Mappings',
#    'type': 'application/json'},
#   {'href': 'http://localhost:5000/classification_systems',
#    'rel': 'self',
#    'title': 'Link to this document',
#    'type': 'application/json'}],
#  'name': 'MapBiomas4.1',
#  'version': '4.1'}

# %%
service.avaliable_mappings(system_id_source='TerraClass_AMZ')
# Out:
# ['PRODES']

# %%
service.mappings(system_id_source='TerraClass_AMZ', system_id_target='PRODES')
# Out:
# {'mappings': [{'degree_of_similarity': 1.0,
#    'description': '',
#    'links': [{'href': 'http://localhost:5000/classification_system/TerraClass_AMZ/classes/Agricultura Anual',
#      'rel': 'item',
#      'title': 'Link to the source class',
#      'type': 'application/json'},
#     {'href': 'http://localhost:5000/classification_system/TerraClass_AMZ/classes/Desmatamento',
#      'rel': 'item',
#      'title': 'Link to target class',
#      'type': 'application/json'}],
#    'source': 'Agricultura Anual',
#    'source_id': 85,
#    'target': 'Desmatamento',
#    'target_id': 175},
#   {'degree_of_similarity': 1.0,
#    'description': '',
#    'links': [{'href': 'http://localhost:5000/classification_system/TerraClass_AMZ/classes/Área Não Observada',
#      'rel': 'item',
#      'title': 'Link to the source class',
#      'type': 'application/json'},
#     {'href': 'http://localhost:5000/classification_system/TerraClass_AMZ/classes/Nuvem',
#      'rel': 'item',
# ...
